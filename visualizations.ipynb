# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    customer_id cust_age    job_title marital_status          education  \
# 0        11218     48.0  blue-collar         single                NaN
# 1        30655     60.0    pensioner        married          secondary
# 2        24190     34.0  blue-collar        married          secondary
# 3        26270     50.0      manager        married  university-degree
# 4        20989     60.0      manager        married  university-degree
#
#   has_default_loan cust_balance has_mortgage_loan has_personal_loan  \
# 0               no         71.0               yes                no
# 1               no        781.0               yes               yes
# 2               no        157.0               yes                no
# 3               no         29.0                no               yes
# 4               no       3301.0                no                no
#
#   contact_channel  contact_day contact_month  contact_duration  campaign  \
# 0             NaN            8           may               101         2
# 1  social-network           12           aug               128         5
# 2  social-network           11           jul               254         2
# 3             NaN           23           jul               104         1
# 4             NaN           17           jun              2621         3
#
#    pdays  previous_contacts previous_outcome  is_subscribed
# 0     -1                  0              NaN          False
# 1     -1                  0              NaN          False
# 2     -1                  0              NaN          False
# 3     -1                  0              NaN          False
# 4     -1                  0              NaN           True

# %%
df.isna().sum()
# Out:
# customer_id              0
# cust_age               307
# job_title              204
# marital_status           0
# education             1325
# has_default_loan         0
# cust_balance           373
# has_mortgage_loan        0
# has_personal_loan        0
# contact_channel       9151
# contact_day              0
# contact_month            0
# contact_duration         0
# campaign                 0
# pdays                    0
# previous_contacts        0
# previous_outcome     25889
# is_subscribed            0
# dtype: int64

# %%
df['job_title'] = df['job_title'].fillna('working-from-home')

# %%
plt.figure(figsize=(12, 12))
plt.xticks(rotation=45)
sns.countplot(data=df, x='job_title', hue='is_subscribed')
# Out:
# <AxesSubplot:xlabel='job_title', ylabel='count'>

# %%
df[['cust_age','cust_balance']] = df[['cust_age','cust_balance']].astype(str)

df['cust_age'] = df['cust_age'].map(lambda df: df.rstrip('/r').rstrip('/'))
df['cust_balance']= df['cust_balance'].map(lambda df: df.rstrip('/r').lstrip('/'))

df['cust_balance'] = df['cust_balance'].str.extract('(\d+)', expand=False)
df['cust_balance']= df['cust_balance'].astype(float)

# %%
sns.jointplot(data=df, x='cust_balance', y='cust_age')

# %%
df.describe()
# Out:
#         customer_id   cust_balance   contact_day  contact_duration  \
# count  31647.000000   31272.000000  31647.000000      31647.000000
# mean   32600.629444    1418.247410     15.741239        258.074035
# std    13073.910176    3045.255888      8.309990        257.898135
# min    10000.000000       0.000000      1.000000          0.000000
# 25%    21240.500000     138.000000      8.000000        103.000000
# 50%    32579.000000     484.000000     16.000000        180.000000
# 75%    43984.000000    1443.000000     21.000000        318.000000
# max    55210.000000  102127.000000     31.000000       4918.000000
#
#            campaign         pdays  previous_contacts
# count  31647.000000  31647.000000       31647.000000
# mean       2.751730     40.198060           0.576800
# std        3.093624    100.228657           1.915562
# min        1.000000     -1.000000           0.000000
# 25%        1.000000     -1.000000           0.000000
# 50%        2.000000     -1.000000           0.000000
# 75%        3.000000     -1.000000           0.000000
# max       63.000000    871.000000          58.000000

# %%
df['pdays'].plot()
# Out:
# <AxesSubplot:>

# %%
df['cus']
